# %%
# DELIVERABLE 1

# %%
# 1. Create a folder called Weather_Database
# 2. Create a new Jupyter Notebook file called Weather_Database to retrieve the weather data

# %%
# Import dependencies
import random
import numpy as np
import pandas as pd

# %%
# 3. Create 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the citipy module
from citipy import citipy
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %%
# 5. Perform an API call with the OpenWeatherMap
import requests
from weather_config import weather_api_key
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | shimoda
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | le port
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | karratha
# Processing Record 6 of Set 1 | conceicao do araguaia
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | clyde river
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | ostrovnoy
# Processing Record 14 of Set 1 | dunedin
# Processing Record 15 of Set 1 | saint-prosper
# Processing Record 16 of Set 1 | ola
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | pemangkat
# Processing Record 19 of Set 1 | klaksvik
# Processing Record 20 of Set 1 | meulaboh
# Processing Record 21 of Set 1 | guiratinga
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | cascais
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | port blair
# Processing Record 28 of Set 1 | pedernales
# Processing Record 29 of Set 1 | black river
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | teguldet
# Processing Record 35 of Set 1 | gayny
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | taoudenni
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | saldanha
# Processing Record 41 of Set 1 | baghdad
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | mahebourg
# Processing Record 48 of Set 1 | sechura
# Processing Record 49 of Set 1 | coquimbo
# Processing Record 50 of Set 1 | mogadouro
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | kahului
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 2 | luderitz
# Processing Record 8 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 2 | gaoual
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | faanui
# Processing Record 12 of Set 2 | altamira
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | bandarbeyla
# Processing Record 15 of Set 2 | zacatepec
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | maniwaki
# Processing Record 19 of Set 2 | oranzherei
# Processing Record 20 of Set 2 | novobirilyussy
# Processing Record 21 of Set 2 | ukiah
# Processing Record 22 of Set 2 | zhangye
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | ugoofaaru
# Processing Record 25 of Set 2 | halifax
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | tuy hoa
# Processing Record 28 of Set 2 | miranda
# Processing Record 29 of Set 2 | rudbar
# Processing Record 30 of Set 2 | bay roberts
# Processing Record 31 of Set 2 | carquefou
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | okhotsk
# Processing Record 34 of Set 2 | grindavik
# Processing Record 35 of Set 2 | eyrarbakki
# Processing Record 36 of Set 2 | mitu
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | portland
# Processing Record 39 of Set 2 | xinqing
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | sorong
# Processing Record 42 of Set 2 | aklavik
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | guasdualito
# Processing Record 45 of Set 2 | avon
# Processing Record 46 of Set 2 | hirara
# Processing Record 47 of Set 2 | timberlake
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | lavrentiya
# Processing Record 50 of Set 2 | hobart
# Processing Record 1 of Set 3 | axim
# Processing Record 2 of Set 3 | bathsheba
# Processing Record 3 of Set 3 | bitung
# Processing Record 4 of Set 3 | shahreza
# Processing Record 5 of Set 3 | yumen
# Processing Record 6 of Set 3 | kilindoni
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | los arabos
# Processing Record 10 of Set 3 | novita
# Processing Record 11 of Set 3 | pangnirtung
# Processing Record 12 of Set 3 | santa cruz de la palma
# Processing Record 13 of Set 3 | mouila
# Processing Record 14 of Set 3 | laguna
# Processing Record 15 of Set 3 | oranjestad
# Processing Record 16 of Set 3 | mehamn
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | turan
# Processing Record 19 of Set 3 | cape town
# Processing Record 20 of Set 3 | norman wells
# Processing Record 21 of Set 3 | san patricio
# Processing Record 22 of Set 3 | severo-kurilsk
# Processing Record 23 of Set 3 | marawi
# Processing Record 24 of Set 3 | taltal
# Processing Record 25 of Set 3 | dubno
# Processing Record 26 of Set 3 | markova
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | alpena
# Processing Record 29 of Set 3 | kainantu
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | bambous virieux
# Processing Record 32 of Set 3 | qasigiannguit
# Processing Record 33 of Set 3 | oistins
# Processing Record 34 of Set 3 | don sak
# Processing Record 35 of Set 3 | aktash
# Processing Record 36 of Set 3 | coahuayana
# Processing Record 37 of Set 3 | barrow
# Processing Record 38 of Set 3 | rawson
# Processing Record 39 of Set 3 | lascahobas
# Processing Record 40 of Set 3 | virginia beach
# Processing Record 41 of Set 3 | sao filipe
# Processing Record 42 of Set 3 | hamilton
# Processing Record 43 of Set 3 | khatanga
# Processing Record 44 of Set 3 | menongue
# Processing Record 45 of Set 3 | lata
# Processing Record 46 of Set 3 | dianopolis
# City not found. Skipping...
# Processing Record 47 of Set 3 | kalmunai
# Processing Record 48 of Set 3 | asosa
# Processing Record 49 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 3 | atamanskaya
# Processing Record 1 of Set 4 | kota kinabalu
# Processing Record 2 of Set 4 | suez
# Processing Record 3 of Set 4 | bukama
# Processing Record 4 of Set 4 | victoria
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | kemijarvi
# Processing Record 7 of Set 4 | moultrie
# Processing Record 8 of Set 4 | staryy nadym
# Processing Record 9 of Set 4 | north platte
# Processing Record 10 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 4 | da nang
# Processing Record 12 of Set 4 | ancud
# Processing Record 13 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 4 | cherskiy
# Processing Record 15 of Set 4 | sovetskaya gavan
# Processing Record 16 of Set 4 | narsaq
# Processing Record 17 of Set 4 | mae hong son
# Processing Record 18 of Set 4 | verkhnevilyuysk
# Processing Record 19 of Set 4 | talnakh
# Processing Record 20 of Set 4 | half moon bay
# Processing Record 21 of Set 4 | cairns
# Processing Record 22 of Set 4 | kajaani
# Processing Record 23 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 4 | katsuura
# Processing Record 25 of Set 4 | brigantine
# Processing Record 26 of Set 4 | fortuna
# Processing Record 27 of Set 4 | raudeberg
# Processing Record 28 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 4 | salumbar
# Processing Record 30 of Set 4 | bengkulu
# Processing Record 31 of Set 4 | torbay
# Processing Record 32 of Set 4 | westport
# Processing Record 33 of Set 4 | constitucion
# Processing Record 34 of Set 4 | khani
# Processing Record 35 of Set 4 | kodiak
# Processing Record 36 of Set 4 | mar del plata
# Processing Record 37 of Set 4 | kohima
# Processing Record 38 of Set 4 | winnemucca
# Processing Record 39 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 4 | severo-yeniseyskiy
# Processing Record 41 of Set 4 | sengiley
# Processing Record 42 of Set 4 | olbia
# Processing Record 43 of Set 4 | nanortalik
# Processing Record 44 of Set 4 | katangli
# Processing Record 45 of Set 4 | san cristobal
# Processing Record 46 of Set 4 | agadez
# Processing Record 47 of Set 4 | saint-philippe
# Processing Record 48 of Set 4 | mount gambier
# Processing Record 49 of Set 4 | san lawrenz
# Processing Record 50 of Set 4 | turbat
# Processing Record 1 of Set 5 | akyab
# Processing Record 2 of Set 5 | lorengau
# Processing Record 3 of Set 5 | miranda de ebro
# Processing Record 4 of Set 5 | makushino
# Processing Record 5 of Set 5 | paka
# Processing Record 6 of Set 5 | lebedinyy
# Processing Record 7 of Set 5 | fairbanks
# Processing Record 8 of Set 5 | winslow
# Processing Record 9 of Set 5 | dingle
# Processing Record 10 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 11 of Set 5 | giyon
# Processing Record 12 of Set 5 | ilulissat
# Processing Record 13 of Set 5 | sainte-marie
# Processing Record 14 of Set 5 | souillac
# Processing Record 15 of Set 5 | sao felipe
# Processing Record 16 of Set 5 | vao
# Processing Record 17 of Set 5 | marquette
# Processing Record 18 of Set 5 | hervey bay
# Processing Record 19 of Set 5 | carnarvon
# Processing Record 20 of Set 5 | noumea
# Processing Record 21 of Set 5 | bud
# Processing Record 22 of Set 5 | camalu
# Processing Record 23 of Set 5 | kalispell
# Processing Record 24 of Set 5 | ossora
# Processing Record 25 of Set 5 | jiazi
# Processing Record 26 of Set 5 | silleda
# Processing Record 27 of Set 5 | quatre cocos
# Processing Record 28 of Set 5 | grand gaube
# Processing Record 29 of Set 5 | northam
# Processing Record 30 of Set 5 | abha
# Processing Record 31 of Set 5 | ulaangom
# Processing Record 32 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 33 of Set 5 | ketchikan
# Processing Record 34 of Set 5 | longyearbyen
# Processing Record 35 of Set 5 | kavieng
# Processing Record 36 of Set 5 | burnie
# Processing Record 37 of Set 5 | deputatskiy
# Processing Record 38 of Set 5 | korla
# Processing Record 39 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 5 | sao jose da coroa grande
# Processing Record 41 of Set 5 | hakui
# Processing Record 42 of Set 5 | pittsburgh
# Processing Record 43 of Set 5 | el real de santa maria
# Processing Record 44 of Set 5 | ati
# Processing Record 45 of Set 5 | sitka
# Processing Record 46 of Set 5 | humberto de campos
# Processing Record 47 of Set 5 | cabildo
# Processing Record 48 of Set 5 | fort nelson
# Processing Record 49 of Set 5 | knysna
# Processing Record 50 of Set 5 | bretten
# Processing Record 1 of Set 6 | avarua
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | bethel
# Processing Record 4 of Set 6 | rocha
# Processing Record 5 of Set 6 | lompoc
# Processing Record 6 of Set 6 | miles city
# Processing Record 7 of Set 6 | concepcion del oro
# Processing Record 8 of Set 6 | port lincoln
# Processing Record 9 of Set 6 | iranshahr
# Processing Record 10 of Set 6 | vardo
# Processing Record 11 of Set 6 | skibbereen
# Processing Record 12 of Set 6 | denau
# City not found. Skipping...
# Processing Record 13 of Set 6 | kangaba
# Processing Record 14 of Set 6 | bertoua
# Processing Record 15 of Set 6 | leningradskiy
# Processing Record 16 of Set 6 | kawalu
# Processing Record 17 of Set 6 | sioux lookout
# Processing Record 18 of Set 6 | charagua
# Processing Record 19 of Set 6 | beloha
# Processing Record 20 of Set 6 | rosarito
# Processing Record 21 of Set 6 | kijang
# Processing Record 22 of Set 6 | oksfjord
# Processing Record 23 of Set 6 | gifhorn
# Processing Record 24 of Set 6 | duku
# Processing Record 25 of Set 6 | hiriyur
# Processing Record 26 of Set 6 | berlevag
# Processing Record 27 of Set 6 | yantal
# Processing Record 28 of Set 6 | nelson bay
# Processing Record 29 of Set 6 | kutum
# Processing Record 30 of Set 6 | prince rupert
# Processing Record 31 of Set 6 | wilkie
# Processing Record 32 of Set 6 | trelew
# Processing Record 33 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 6 | san quintin
# Processing Record 35 of Set 6 | san carlos de bariloche
# Processing Record 36 of Set 6 | geraldton
# Processing Record 37 of Set 6 | beringovskiy
# Processing Record 38 of Set 6 | helong
# Processing Record 39 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 6 | banda aceh
# Processing Record 41 of Set 6 | lyubeshiv
# City not found. Skipping...
# Processing Record 42 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 6 | tiksi
# Processing Record 44 of Set 6 | jieshi
# Processing Record 45 of Set 6 | ust-omchug
# Processing Record 46 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 47 of Set 6 | ahuimanu
# Processing Record 48 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 49 of Set 6 | thenzawl
# Processing Record 50 of Set 6 | waverly
# Processing Record 1 of Set 7 | el badari
# City not found. Skipping...
# Processing Record 2 of Set 7 | east london
# Processing Record 3 of Set 7 | biak
# Processing Record 4 of Set 7 | rawicz
# Processing Record 5 of Set 7 | margate
# Processing Record 6 of Set 7 | saint-pierre
# Processing Record 7 of Set 7 | manbij
# Processing Record 8 of Set 7 | cayenne
# Processing Record 9 of Set 7 | vanimo
# Processing Record 10 of Set 7 | tangshan
# Processing Record 11 of Set 7 | aquin
# Processing Record 12 of Set 7 | bilibino
# Processing Record 13 of Set 7 | yenagoa
# Processing Record 14 of Set 7 | arroio grande
# Processing Record 15 of Set 7 | kaitangata
# Processing Record 16 of Set 7 | ponta do sol
# Processing Record 17 of Set 7 | singaraja
# Processing Record 18 of Set 7 | ordubad
# Processing Record 19 of Set 7 | blackwater
# Processing Record 20 of Set 7 | yaan
# Processing Record 21 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 7 | mount isa
# Processing Record 23 of Set 7 | vengerovo
# Processing Record 24 of Set 7 | chalinze
# Processing Record 25 of Set 7 | ginir
# Processing Record 26 of Set 7 | sayyan
# Processing Record 27 of Set 7 | jinhua
# Processing Record 28 of Set 7 | kikwit
# Processing Record 29 of Set 7 | sunland park
# Processing Record 30 of Set 7 | hofn
# Processing Record 31 of Set 7 | gari
# Processing Record 32 of Set 7 | hovd
# Processing Record 33 of Set 7 | vavozh
# Processing Record 34 of Set 7 | baykit
# Processing Record 35 of Set 7 | esperance
# Processing Record 36 of Set 7 | alofi
# Processing Record 37 of Set 7 | qaqortoq
# Processing Record 38 of Set 7 | rio gallegos
# Processing Record 39 of Set 7 | prien
# Processing Record 40 of Set 7 | vila velha
# Processing Record 41 of Set 7 | wattegama
# Processing Record 42 of Set 7 | tuatapere
# Processing Record 43 of Set 7 | selfoss
# Processing Record 44 of Set 7 | batticaloa
# Processing Record 45 of Set 7 | puerto escondido
# Processing Record 46 of Set 7 | lasa
# Processing Record 47 of Set 7 | lamar
# Processing Record 48 of Set 7 | pochutla
# Processing Record 49 of Set 7 | bar harbor
# Processing Record 50 of Set 7 | marienburg
# Processing Record 1 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 2 of Set 8 | mayumba
# Processing Record 3 of Set 8 | lyuban
# Processing Record 4 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 8 | maniitsoq
# Processing Record 6 of Set 8 | fomboni
# Processing Record 7 of Set 8 | asau
# Processing Record 8 of Set 8 | shalyhyne
# Processing Record 9 of Set 8 | talgar
# Processing Record 10 of Set 8 | xai-xai
# Processing Record 11 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 8 | dandong
# Processing Record 13 of Set 8 | boende
# Processing Record 14 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 8 | sampit
# Processing Record 16 of Set 8 | sanda
# Processing Record 17 of Set 8 | vestmannaeyjar
# Processing Record 18 of Set 8 | shu
# Processing Record 19 of Set 8 | barrinha
# Processing Record 20 of Set 8 | chumikan
# Processing Record 21 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 8 | ballina
# Processing Record 23 of Set 8 | havelock
# Processing Record 24 of Set 8 | namibe
# Processing Record 25 of Set 8 | sabha
# Processing Record 26 of Set 8 | show low
# Processing Record 27 of Set 8 | guozhen
# Processing Record 28 of Set 8 | moelv
# Processing Record 29 of Set 8 | mansehra
# Processing Record 30 of Set 8 | zeerust
# Processing Record 31 of Set 8 | olga
# Processing Record 32 of Set 8 | svetlaya
# Processing Record 33 of Set 8 | bawku
# Processing Record 34 of Set 8 | champerico
# Processing Record 35 of Set 8 | harur
# Processing Record 36 of Set 8 | marzuq
# Processing Record 37 of Set 8 | sakakah
# Processing Record 38 of Set 8 | mizdah
# Processing Record 39 of Set 8 | liverpool
# Processing Record 40 of Set 8 | ahipara
# Processing Record 41 of Set 8 | yuancheng
# Processing Record 42 of Set 8 | kruisfontein
# Processing Record 43 of Set 8 | mananara
# Processing Record 44 of Set 8 | sassenberg
# Processing Record 45 of Set 8 | balkanabat
# Processing Record 46 of Set 8 | kalabo
# Processing Record 47 of Set 8 | sarangani
# Processing Record 48 of Set 8 | balakhninskiy
# Processing Record 49 of Set 8 | palmer
# Processing Record 50 of Set 8 | flin flon
# Processing Record 1 of Set 9 | sao gabriel da cachoeira
# Processing Record 2 of Set 9 | korocha
# Processing Record 3 of Set 9 | nikel
# Processing Record 4 of Set 9 | kenai
# Processing Record 5 of Set 9 | san vicente
# Processing Record 6 of Set 9 | baleshwar
# Processing Record 7 of Set 9 | tual
# Processing Record 8 of Set 9 | camopi
# Processing Record 9 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 9 | mahajanga
# Processing Record 11 of Set 9 | lufilufi
# Processing Record 12 of Set 9 | kabanjahe
# Processing Record 13 of Set 9 | hakkari
# Processing Record 14 of Set 9 | zaraza
# Processing Record 15 of Set 9 | saskylakh
# Processing Record 16 of Set 9 | morshansk
# Processing Record 17 of Set 9 | aracati
# Processing Record 18 of Set 9 | goundi
# Processing Record 19 of Set 9 | magistralnyy
# Processing Record 20 of Set 9 | x-can
# City not found. Skipping...
# Processing Record 21 of Set 9 | shenjiamen
# Processing Record 22 of Set 9 | sur
# Processing Record 23 of Set 9 | opuwo
# Processing Record 24 of Set 9 | nuevo progreso
# Processing Record 25 of Set 9 | kungurtug
# Processing Record 26 of Set 9 | lagoa
# Processing Record 27 of Set 9 | kansanshi
# Processing Record 28 of Set 9 | aurdal
# Processing Record 29 of Set 9 | marsh harbour
# Processing Record 30 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 9 | amapa
# Processing Record 32 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 33 of Set 9 | letychiv
# Processing Record 34 of Set 9 | nuneaton
# Processing Record 35 of Set 9 | afonso claudio
# Processing Record 36 of Set 9 | pucara
# Processing Record 37 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 9 | goderich
# Processing Record 39 of Set 9 | sao felix do xingu
# Processing Record 40 of Set 9 | chibombo
# Processing Record 41 of Set 9 | swan river
# Processing Record 42 of Set 9 | susanville
# Processing Record 43 of Set 9 | storforshei
# Processing Record 44 of Set 9 | clonakilty
# Processing Record 45 of Set 9 | inhambane
# Processing Record 46 of Set 9 | ostersund
# Processing Record 47 of Set 9 | tenenkou
# Processing Record 48 of Set 9 | wanning
# Processing Record 49 of Set 9 | sarkand
# Processing Record 50 of Set 9 | general roca
# Processing Record 1 of Set 10 | sisimiut
# Processing Record 2 of Set 10 | flinders
# Processing Record 3 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 10 | longido
# Processing Record 5 of Set 10 | luganville
# Processing Record 6 of Set 10 | ha
# City not found. Skipping...
# Processing Record 7 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 9 of Set 10 | slyudyanka
# Processing Record 10 of Set 10 | nome
# Processing Record 11 of Set 10 | launceston
# Processing Record 12 of Set 10 | hirado
# Processing Record 13 of Set 10 | matara
# Processing Record 14 of Set 10 | killybegs
# Processing Record 15 of Set 10 | san lazaro
# Processing Record 16 of Set 10 | hengyang
# Processing Record 17 of Set 10 | kindersley
# Processing Record 18 of Set 10 | codrington
# Processing Record 19 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 10 | dalianwan
# Processing Record 21 of Set 10 | olafsvik
# Processing Record 22 of Set 10 | mana
# Processing Record 23 of Set 10 | villeta
# Processing Record 24 of Set 10 | broome
# Processing Record 25 of Set 10 | kavaratti
# Processing Record 26 of Set 10 | greystones
# Processing Record 27 of Set 10 | alakurtti
# Processing Record 28 of Set 10 | kibala
# Processing Record 29 of Set 10 | nadym
# Processing Record 30 of Set 10 | ushtobe
# Processing Record 31 of Set 10 | solwezi
# Processing Record 32 of Set 10 | tucuman
# Processing Record 33 of Set 10 | itacare
# Processing Record 34 of Set 10 | isabela
# Processing Record 35 of Set 10 | barrhead
# Processing Record 36 of Set 10 | najran
# Processing Record 37 of Set 10 | chimoio
# Processing Record 38 of Set 10 | prado
# Processing Record 39 of Set 10 | kushima
# Processing Record 40 of Set 10 | ocampo
# Processing Record 41 of Set 10 | kovdor
# Processing Record 42 of Set 10 | turukhansk
# Processing Record 43 of Set 10 | chapais
# Processing Record 44 of Set 10 | batemans bay
# Processing Record 45 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 10 | itarema
# Processing Record 47 of Set 10 | bondo
# Processing Record 48 of Set 10 | guangyuan
# Processing Record 49 of Set 10 | vila franca do campo
# Processing Record 50 of Set 10 | katete
# Processing Record 1 of Set 11 | key west
# Processing Record 2 of Set 11 | tezu
# Processing Record 3 of Set 11 | ucluelet
# Processing Record 4 of Set 11 | znamenskoye
# Processing Record 5 of Set 11 | nuristan
# Processing Record 6 of Set 11 | campobello di mazara
# Processing Record 7 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 8 of Set 11 | matagami
# Processing Record 9 of Set 11 | plettenberg bay
# Processing Record 10 of Set 11 | vilyuysk
# Processing Record 11 of Set 11 | karema
# Processing Record 12 of Set 11 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 13 of Set 11 | rubtsovsk
# Processing Record 14 of Set 11 | keetmanshoop
# Processing Record 15 of Set 11 | merzifon
# Processing Record 16 of Set 11 | iskateley
# Processing Record 17 of Set 11 | alice springs
# Processing Record 18 of Set 11 | poum
# Processing Record 19 of Set 11 | pestera
# Processing Record 20 of Set 11 | grand-santi
# Processing Record 21 of Set 11 | baker city
# Processing Record 22 of Set 11 | cidreira
# Processing Record 23 of Set 11 | bokoro
# Processing Record 24 of Set 11 | tura
# Processing Record 25 of Set 11 | ternate
# Processing Record 26 of Set 11 | barcelos
# Processing Record 27 of Set 11 | santa barbara
# Processing Record 28 of Set 11 | walvis bay
# Processing Record 29 of Set 11 | pinerolo
# Processing Record 30 of Set 11 | vinh
# Processing Record 31 of Set 11 | sylva
# Processing Record 32 of Set 11 | pevek
# Processing Record 33 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 11 | palu
# Processing Record 35 of Set 11 | la orilla
# Processing Record 36 of Set 11 | bhabua
# Processing Record 37 of Set 11 | sychevka
# Processing Record 38 of Set 11 | krasnovishersk
# Processing Record 39 of Set 11 | vila
# Processing Record 40 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 11 | zharkent
# Processing Record 42 of Set 11 | oranjemund
# Processing Record 43 of Set 11 | ubinskoye
# Processing Record 44 of Set 11 | pangoa
# Processing Record 45 of Set 11 | imperia
# Processing Record 46 of Set 11 | egvekinot
# Processing Record 47 of Set 11 | salalah
# Processing Record 48 of Set 11 | morristown
# Processing Record 49 of Set 11 | smithers
# Processing Record 50 of Set 11 | kuminskiy
# Processing Record 1 of Set 12 | ambovombe
# Processing Record 2 of Set 12 | zhigansk
# Processing Record 3 of Set 12 | raymondville
# Processing Record 4 of Set 12 | zarand
# Processing Record 5 of Set 12 | guerrero negro
# Processing Record 6 of Set 12 | kysyl-syr
# Processing Record 7 of Set 12 | jos
# Processing Record 8 of Set 12 | zheshart
# Processing Record 9 of Set 12 | numan
# Processing Record 10 of Set 12 | de aar
# Processing Record 11 of Set 12 | ofaqim
# Processing Record 12 of Set 12 | alcaniz
# Processing Record 13 of Set 12 | santa isabel do rio negro
# Processing Record 14 of Set 12 | porto seguro
# Processing Record 15 of Set 12 | rock sound
# Processing Record 16 of Set 12 | tunghsiao
# City not found. Skipping...
# Processing Record 17 of Set 12 | chake chake
# Processing Record 18 of Set 12 | hasaki
# Processing Record 19 of Set 12 | uyuni
# Processing Record 20 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 12 | itoman
# Processing Record 22 of Set 12 | sangueya
# Processing Record 23 of Set 12 | kendrapara
# Processing Record 24 of Set 12 | salta
# Processing Record 25 of Set 12 | brandon
# Processing Record 26 of Set 12 | la romana
# Processing Record 27 of Set 12 | nouadhibou
# Processing Record 28 of Set 12 | soure
# Processing Record 29 of Set 12 | sal rei
# Processing Record 30 of Set 12 | paso de los toros
# Processing Record 31 of Set 12 | bac can
# City not found. Skipping...
# Processing Record 32 of Set 12 | fukue
# Processing Record 33 of Set 12 | mikhaylovka
# Processing Record 34 of Set 12 | joshimath
# Processing Record 35 of Set 12 | miyako
# Processing Record 36 of Set 12 | padang
# Processing Record 37 of Set 12 | ust-nera
# Processing Record 38 of Set 12 | coihaique
# Processing Record 39 of Set 12 | canhotinho
# Processing Record 40 of Set 12 | erenhot
# Processing Record 41 of Set 12 | arlit
# Processing Record 42 of Set 12 | bojaya
# City not found. Skipping...
# Processing Record 43 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 12 | kollo
# Processing Record 45 of Set 12 | mandalgovi
# Processing Record 46 of Set 12 | tieling
# Processing Record 47 of Set 12 | hong gai
# Processing Record 48 of Set 12 | puerto madryn
# Processing Record 49 of Set 12 | banjar
# Processing Record 50 of Set 12 | bobrovka
# Processing Record 1 of Set 13 | omsukchan
# Processing Record 2 of Set 13 | armidale
# Processing Record 3 of Set 13 | greenwood
# Processing Record 4 of Set 13 | husavik
# Processing Record 5 of Set 13 | srednekolymsk
# Processing Record 6 of Set 13 | ponta delgada
# Processing Record 7 of Set 13 | chugunash
# City not found. Skipping...
# Processing Record 8 of Set 13 | arroyo
# Processing Record 9 of Set 13 | wukari
# Processing Record 10 of Set 13 | inuvik
# Processing Record 11 of Set 13 | komsomolskiy
# Processing Record 12 of Set 13 | bubaque
# Processing Record 13 of Set 13 | solnechnyy
# Processing Record 14 of Set 13 | mindelo
# Processing Record 15 of Set 13 | dubai
# Processing Record 16 of Set 13 | port hardy
# Processing Record 17 of Set 13 | udachnyy
# Processing Record 18 of Set 13 | oktyabrskiy
# Processing Record 19 of Set 13 | otane
# Processing Record 20 of Set 13 | khandyga
# Processing Record 21 of Set 13 | chegdomyn
# Processing Record 22 of Set 13 | frederico westphalen
# Processing Record 23 of Set 13 | cap-aux-meules
# Processing Record 24 of Set 13 | sendafa
# Processing Record 25 of Set 13 | nkoteng
# Processing Record 26 of Set 13 | peleduy
# Processing Record 27 of Set 13 | graaff-reinet
# Processing Record 28 of Set 13 | poso
# Processing Record 29 of Set 13 | la ronge
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 576

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Shimoda  34.6667  138.9500     58.14        67          91
# 1              Busselton -33.6500  115.3333     53.10        82          30
# 2                Le Port -20.9373   55.2919     75.20        95          55
# 3                Rikitea -23.1203 -134.9692     74.71        82          72
# 4               Karratha -20.7377  116.8463     80.31        41          83
# 5  Conceicao Do Araguaia  -8.2578  -49.2647     87.71        58          87
# 6            Yellowknife  62.4560 -114.3525     42.42        79          40
# 7            Port Alfred -33.5906   26.8910     61.20        70          27
# 8            New Norfolk -42.7826  147.0587     51.66        82         100
# 9                Iqaluit  63.7506  -68.5145     31.73        69          40
#
#    Wind Speed Country Current Description
# 0       10.78      JP     overcast clouds
# 1        6.26      AU    scattered clouds
# 2        7.92      RE       broken clouds
# 3       19.44      PF       broken clouds
# 4        6.64      AU       broken clouds
# 5        5.88      BR     overcast clouds
# 6       19.57      CA    scattered clouds
# 7       29.28      ZA    scattered clouds
# 8        5.01      AU          light rain
# 9        2.30      CA    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Shimoda      JP  34.6667  138.9500     58.14        67          91
# 1        Busselton      AU -33.6500  115.3333     53.10        82          30
# 2          Le Port      RE -20.9373   55.2919     75.20        95          55
# 3          Rikitea      PF -23.1203 -134.9692     74.71        82          72
# 4         Karratha      AU -20.7377  116.8463     80.31        41          83
# ..             ...     ...      ...       ...       ...       ...         ...
# 571        Nkoteng      CM   4.5167   12.0333     70.52        91          46
# 572        Peleduy      RU  59.6289  112.7406     37.18        90         100
# 573  Graaff-Reinet      ZA -32.2522   24.5308     59.92        52          71
# 574           Poso      ID  -1.3959  120.7524     76.12        85          98
# 575       La Ronge      CA  55.1001 -105.2842     35.85        75          90
#
#      Wind Speed Current Description
# 0         10.78     overcast clouds
# 1          6.26    scattered clouds
# 2          7.92       broken clouds
# 3         19.44       broken clouds
# 4          6.64       broken clouds
# ..          ...                 ...
# 571        2.95    scattered clouds
# 572       10.04          light rain
# 573       16.33       broken clouds
# 574        4.79     overcast clouds
# 575       14.97     overcast clouds
#
# [576 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
