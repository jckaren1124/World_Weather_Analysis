# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from vacation_config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID       City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0    Shimoda      JP  34.6667  138.9500     58.14        67
# 1        1  Busselton      AU -33.6500  115.3333     53.10        82
# 2        2    Le Port      RE -20.9373   55.2919     75.20        95
# 3        3    Rikitea      PF -23.1203 -134.9692     74.71        82
# 4        4   Karratha      AU -20.7377  116.8463     80.31        41
#
#    Cloudiness  Wind Speed Current Description
# 0          91       10.78     overcast clouds
# 1          30        6.26    scattered clouds
# 2          55        7.92       broken clouds
# 3          72       19.44       broken clouds
# 4          83        6.64       broken clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 60
# What is the maximum temperature you would like for your trip? 85

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 2         2         Le Port      RE -20.9373   55.2919     75.20        95
# 3         3         Rikitea      PF -23.1203 -134.9692     74.71        82
# 4         4        Karratha      AU -20.7377  116.8463     80.31        41
# 7         7     Port Alfred      ZA -33.5906   26.8910     61.20        70
# 11       11            Hilo      US  19.7297 -155.0900     73.26        96
# 17       17       Pemangkat      ID   1.1667  108.9667     78.71        80
# 19       19        Meulaboh      ID   4.1363   96.1285     76.87        89
# 22       22         Cascais      PT  38.6979   -9.4215     72.75        52
# 24       24  Ribeira Grande      PT  38.5167  -28.7000     72.00        60
# 26       26      Port Blair      IN  11.6667   92.7500     80.42        78
#
#     Cloudiness  Wind Speed Current Description
# 2           55        7.92       broken clouds
# 3           72       19.44       broken clouds
# 4           83        6.64       broken clouds
# 7           27       29.28    scattered clouds
# 11          90        5.75       moderate rain
# 17          98        2.44     overcast clouds
# 19          94        2.89     overcast clouds
# 22           0        6.91           clear sky
# 24          20       10.36          few clouds
# 26          90        1.83     overcast clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                255
# City                   255
# Country                252
# Lat                    255
# Lng                    255
# Max Temp               255
# Humidity               255
# Cloudiness             255
# Wind Speed             255
# Current Description    255
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
updated_preferred_cities_df = preferred_cities_df.dropna()
updated_preferred_cities_df.count()
# Out:
# City_ID                252
# City                   252
# Country                252
# Lat                    252
# Lng                    252
# Max Temp               252
# Humidity               252
# Cloudiness             252
# Wind Speed             252
# Current Description    252
# dtype: int64

# %%
updated_preferred_cities_df.head(10)
# Out:
#     City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 2         2         Le Port      RE -20.9373   55.2919     75.20        95
# 3         3         Rikitea      PF -23.1203 -134.9692     74.71        82
# 4         4        Karratha      AU -20.7377  116.8463     80.31        41
# 7         7     Port Alfred      ZA -33.5906   26.8910     61.20        70
# 11       11            Hilo      US  19.7297 -155.0900     73.26        96
# 17       17       Pemangkat      ID   1.1667  108.9667     78.71        80
# 19       19        Meulaboh      ID   4.1363   96.1285     76.87        89
# 22       22         Cascais      PT  38.6979   -9.4215     72.75        52
# 24       24  Ribeira Grande      PT  38.5167  -28.7000     72.00        60
# 26       26      Port Blair      IN  11.6667   92.7500     80.42        78
#
#     Cloudiness  Wind Speed Current Description
# 2           55        7.92       broken clouds
# 3           72       19.44       broken clouds
# 4           83        6.64       broken clouds
# 7           27       29.28    scattered clouds
# 11          90        5.75       moderate rain
# 17          98        2.44     overcast clouds
# 19          94        2.89     overcast clouds
# 22           0        6.91           clear sky
# 24          20       10.36          few clouds
# 26          90        1.83     overcast clouds

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = updated_preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 2          Le Port      RE     75.20       broken clouds -20.9373   55.2919
# 3          Rikitea      PF     74.71       broken clouds -23.1203 -134.9692
# 4         Karratha      AU     80.31       broken clouds -20.7377  116.8463
# 7      Port Alfred      ZA     61.20    scattered clouds -33.5906   26.8910
# 11            Hilo      US     73.26       moderate rain  19.7297 -155.0900
# 17       Pemangkat      ID     78.71     overcast clouds   1.1667  108.9667
# 19        Meulaboh      ID     76.87     overcast clouds   4.1363   96.1285
# 22         Cascais      PT     72.75           clear sky  38.6979   -9.4215
# 24  Ribeira Grande      PT     72.00          few clouds  38.5167  -28.7000
# 26      Port Blair      IN     80.42     overcast clouds  11.6667   92.7500
#
#    Hotel Name
# 2
# 3
# 4
# 7
# 11
# 17
# 19
# 22
# 24
# 26

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        print(hotels["results"][0]["name"])
    except (IndexError):
        print("Hotel not found... skipping")
# Out:
# KORBEY D'OR OUEST
# People ThankYou
# ibis Styles Karratha
# The Halyards Hotel
# Hilo Hawaiian Hotel
# Ramah Kost KITA
# Kost Pria
# Hotel Vila Galé Cascais
# Quinta da Meia Eira
# Welcomhotel By ITC Hotels, Bay Island, Port Blair
# Villa Enata
# 39 On Nile Guest House
# Blue Bay Lodge
# Baghdad Hotel
# Keleti Beach Resort
# Pousada Porto Praia
# Shandrani Beachcomber Resort & Spa
# Hospedaje Costa Bella
# Punto de encuentro
# Sheraton Kauai Coconut Beach Resort
# Maui Seaside Hotel
# Juvinal Martin
# Hotel koliba
# Bora-Bora Pearl Beach Resort & Spa
# Requinte Hotel
# JABIR HOTEL
# Villas El Paraíso
# CHACARA BAILLY
# Ungoofaaru Inn
# Hotel Halifax
# CenDeluxe Hotel Tuy Hoa
# unidiversidad organica la utopia
# Hotel not found... skipping
# Stonewall Inn
# Scoop Guest House
# waigo splash hotel
# Hotel Atoll Emerald Miyakojima
# Timberlake Motel
# Axim Beach Resort And Spa
# K2 Lembeh
# Bustani B&B
# Isles Sunset Lodge
# B/ Buenos Aires Sector Las Curvitas
# H10 Taburiente Playa
# Hôtel du Lac Bleu
# Holiday Inn Express & Suites Elk Grove Central - Hwy 99, an IHG Hotel
# Sun River Hotel
# Southern Sun Waterfront Cape Town
# Derogongan Residence
# Residencial Karime
# Finch Bay Galapagos Hotel
# Hotel San Isidro Oficial
# Casa Tia Villa
# Sea Sun Moon Hostel
# Hilton Virginia Beach Oceanfront
# Hotel Xaguate
# Six Acres Bed & Breakfast
# Ritz Lauca
# Casa Maquia
# VS Villa
# Blendana Hotel Assosa
# Gaya Centre Hotel
# Green House
# Hotel not found... skipping
# Mini Hotel Central
# Cititel Penang
# Moultrie Inn
# Sun River Hotel
# Baiyoke Chalet Hotel
# The Ritz-Carlton, Half Moon Bay
# Mantra Trilogy Cairns
# Legacy Vacation Resorts Brigantine Beach
# chatra chaya guest house
# Grage Hotel Bengkulu
# Gallows Cove
# The Westport Inn
# Gran Hotel Mar del Plata
# Hotel Centrale Olbia
# Posada Villaven C.A.
# Chambres d'hôte "La Trinité"
# San Andrea Hotel
# Mubashar Quarters
# Hotel Memory
# Lorengau Harbourside Hotel
# RUMBIA RESORT VILLA
# Best Western Plus Winslow Inn
# SEGAYA PROPERTY
# Les pailles en queue de Sainte Marie
# Shanti Maurice Resort & Spa
# Hotel not found... skipping
# Hotel Kou-Bugny
# Shelly Bay Resort
# Hospitality Carnarvon
# Hôtel Le Lagon
# La Cueva del Pirata
# Hotel Jin Hao
# Sunrise Attitude Hotel
# Veranda Paul et Virginie Hotel & Spa
# Abha Hotel
# Nusa Island Retreat
# Crôa Mares Hotel
# Hotel not found... skipping
# Amanecer
# Paradise Inn
# Nuevo Hotel Plaza
# Beleza Pura B&B
# Holiday Inn Express Lompoc, an IHG Hotel
# Hotel Hacienda San Javier
# نیک سرشت
# CAF (case de l´amitié et de la fraternité)
# Hotel De Paris
# KOSAN UNGU UNSIK
# Hotel not found... skipping
# Hotel Festival Plaza Rosarito
# Hotel not found... skipping
# Royal Inn
# Mantra Nelson Bay
# Dibbo areaمنطقة دبو
# Hotel Touring Club
# Don Eddie's Sport Fishing Center
# Sulthan Hotel International
# Yuehai Hotel
# Paradise Bay Resort
# LH Ngaihzuala Garden
# Tu Casa
# Penginapan Kim
# Lindsey Hôtel
# Hôtel Le Dronmi
# Vahmoneh Lodge Vanimo
# Asheev Beach
# Aridolf Resort Wellness and Spa
# Motel Bela Vista
# Hotel do Campo
# Puri Bagus Lovina Resort
# Blackwater Motor Inn
# Hotel not found... skipping
# ibis Styles Mt Isa Verona
# Dolphin Guesthouse
# HOTEL PLACE YALABA
# SpringHill Suites by Marriott El Paso
# Taloa Heights
# L'Auberge Casino Resort Lake Charles
# Quality Suites Vila Velha
# Hotel not found... skipping
# Grand Star Guest House
# Aldea del Bazar Hotel and Spa
# Kings Inn Paris TX
# Hotel Posada San Jose
# LIKWALE LODGE
# Auberge les abou
# Complexo da Familia
# Hotel not found... skipping
# Aquarius Boutique Hotel Sampit
# Ramada Hotel & Suites by Wyndham Ballina Byron
# Sherwood Motel
# Hotel Chik Chik Namibe
# Hampton Inn & Suites Show Low-Pinetop
# Kareespruit Game Ranch and Guest House
# Sraswathi Lodge
# Hotel not found... skipping
# Fakhamat Al Orjoana Apartment
# محمدالمبروك الاريقط
# Chez Roger
# Nebitchi Hotel
# Sikakubete Guest House Kalabo Town Council
# Ballistic Islet
# Complejo Turístico Farelluk
# Banjara Hotels Pvt Ltd
# Grand Vilia Hotel
# La pousada
# Restaurant Greedy Coco Lodge Majunga
# Leuaina Beach Resort and Spa
# Kos-Kosan wanita muslim bagoes kabanjahe
# Hotel not found... skipping
# Jinjiang Inn Zhoushan Putuo Shenjiamen
# Sur Plaza Hotel
# Casa Das Faias
# Hotel not found... skipping
# Abaco Beach Resort
# Pousada Afonso Cláudio
# Chibombo District Council Guest House
# Oceano
# Paradise Hotel
# Hotel y Casino del Río General Roca
# Shellharbour Resort & Conference Centre
# Longido Mountain Lodge
# The Espiritu Hotel
# Samson Hotel
# Amaloh Boutique Resort
# Hotel not found... skipping
# LE SAMANA
# Hotel Villeta Suite
# Hotels in Lakshadweep Islands
# Country Lodge Solwezi
# Dallas Hotel Tucuman
# Ecoporan Hotel Charme Spa & Eventos
# Isawad Resort
# محمد هادي ال فطيح
# Predio Livraria Ahmed
# INN CORNER RIVER - PRADO - BAHIA - HOUSING AND HOTEL
# Casa de ratas
# Hotel not found... skipping
# Pestana Bahia Praia
# Hotel not found... skipping
# Circuit House
# BED AND BREAKFAST CASA VACANZA DA MATI CAMPOBELLO DI MAZARA
# Hotel not found... skipping
# Desert Palms Alice Springs
# Gîte kajeon
# Hotel not found... skipping
# Hotel Castelo
# Hotel RIKMAN Continental
# Grand Dafam Bela Ternate
# Hotel Do Terço
# Upper Ballard Campground
# Khách Sạn Thương Mại
# Hotel Santika Palu
# Baymont by Wyndham Lazaro Cardenas
# Kohinoor Hotel
# La Stregatta
# HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel
# Days Inn by Wyndham Morristown
# RELAHARA
# Casa Laguna, Bed & Breakfast
# Silk Suites
# Zangun Motel
# The Negev Experience
# Porto Cálem Praia Hotel
# Rock Sound Club
# Hotel Archipelago
# Hostal La Magia de Uyuni
# Southern Beach Hotel & Resort Okinawa
# Hotel not found... skipping
# Hotel Mayuri Palace
# Hotel Alejandro I
# El Medina
# Casarão da Amazônia
# Marine Club Beach Resort
# Complejo Isabelino
# Goto Guesthouse Utojuku & SA Car Rental
# Mercure Padang
# Hạ Long DC Hotel
# Hotel Tolosa
# The Hamsa Resort
# Quality Inn Greenwood Hwy 25
# Vila Nova Hotel
# Elimtop
# Casa Dora, Bubaque
# Hotel Gaudi
# Hotel Palace Frederico
# Résidence OOCLO-Cannelle
# Hotel 77 Poso

# %%
hotel_df.head(33)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 2           Le Port      RE     75.20       broken clouds -20.9373   55.2919
# 3           Rikitea      PF     74.71       broken clouds -23.1203 -134.9692
# 4          Karratha      AU     80.31       broken clouds -20.7377  116.8463
# 7       Port Alfred      ZA     61.20    scattered clouds -33.5906   26.8910
# 11             Hilo      US     73.26       moderate rain  19.7297 -155.0900
# 17        Pemangkat      ID     78.71     overcast clouds   1.1667  108.9667
# 19         Meulaboh      ID     76.87     overcast clouds   4.1363   96.1285
# 22          Cascais      PT     72.75           clear sky  38.6979   -9.4215
# 24   Ribeira Grande      PT     72.00          few clouds  38.5167  -28.7000
# 26       Port Blair      IN     80.42     overcast clouds  11.6667   92.7500
# 29           Atuona      PF     78.06          few clouds  -9.8000 -139.0333
# 30   Port Elizabeth      ZA     61.11          few clouds -33.9180   25.5701
# 37         Saldanha      ZA     60.85    scattered clouds -33.0117   17.9442
# 38          Baghdad      IQ     76.91    scattered clouds  33.3406   44.4009
# 40            Vaini      TO     69.96       broken clouds -21.2000 -175.2000
# 41  Arraial Do Cabo      BR     78.76           clear sky -22.9661  -42.0278
# 44        Mahebourg      MU     75.49    scattered clouds -20.4081   57.7000
# 45          Sechura      PE     76.10     overcast clouds  -5.5569  -80.8222
# 46         Coquimbo      CL     60.53          few clouds -29.9533  -71.3436
# 48            Kapaa      US     75.52          light rain  22.0752 -159.3190
# 49          Kahului      US     76.84          few clouds  20.8947 -156.4700
# 50            Airai      TL     61.50       broken clouds  -8.9266  125.4092
# 53           Gaoual      GN     79.43     overcast clouds  11.7500  -13.2000
# 54           Faanui      PF     77.20     overcast clouds -16.4833 -151.7500
# 55         Altamira      BR     84.29          light rain  -3.2033  -52.2064
# 57      Bandarbeyla      SO     78.55           clear sky   9.4942   50.8122
# 58        Zacatepec      MX     81.37     overcast clouds  18.6500  -99.2000
# 65           Castro      BR     74.01          light rain -24.7911  -50.0119
# 66        Ugoofaaru      MV     81.63    scattered clouds   5.6667   73.0000
# 67          Halifax      CA     65.41     overcast clouds  44.6453  -63.5724
# 68          Tuy Hoa      VN     75.60     overcast clouds  13.0833  109.3000
# 69          Miranda      CO     80.65     overcast clouds   3.2499  -76.2281
# 70           Rudbar      AF     60.53           clear sky  30.1500   62.6000
#
#                                            Hotel Name
# 2                                   KORBEY D'OR OUEST
# 3                                     People ThankYou
# 4                                ibis Styles Karratha
# 7                                  The Halyards Hotel
# 11                                Hilo Hawaiian Hotel
# 17                                    Ramah Kost KITA
# 19                                          Kost Pria
# 22                            Hotel Vila Galé Cascais
# 24                                Quinta da Meia Eira
# 26  Welcomhotel By ITC Hotels, Bay Island, Port Blair
# 29                                        Villa Enata
# 30                             39 On Nile Guest House
# 37                                     Blue Bay Lodge
# 38                                      Baghdad Hotel
# 40                                Keleti Beach Resort
# 41                                Pousada Porto Praia
# 44                 Shandrani Beachcomber Resort & Spa
# 45                              Hospedaje Costa Bella
# 46                                 Punto de encuentro
# 48                Sheraton Kauai Coconut Beach Resort
# 49                                 Maui Seaside Hotel
# 50                                     Juvinal Martin
# 53                                       Hotel koliba
# 54                 Bora-Bora Pearl Beach Resort & Spa
# 55                                     Requinte Hotel
# 57                                        JABIR HOTEL
# 58                                  Villas El Paraíso
# 65                                     CHACARA BAILLY
# 66                                     Ungoofaaru Inn
# 67                                      Hotel Halifax
# 68                            CenDeluxe Hotel Tuy Hoa
# 69                   unidiversidad organica la utopia
# 70

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df[hotel_df["Hotel Name"]!= ""]
clean_hotel_df.head(33)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 2           Le Port      RE     75.20       broken clouds -20.9373   55.2919
# 3           Rikitea      PF     74.71       broken clouds -23.1203 -134.9692
# 4          Karratha      AU     80.31       broken clouds -20.7377  116.8463
# 7       Port Alfred      ZA     61.20    scattered clouds -33.5906   26.8910
# 11             Hilo      US     73.26       moderate rain  19.7297 -155.0900
# 17        Pemangkat      ID     78.71     overcast clouds   1.1667  108.9667
# 19         Meulaboh      ID     76.87     overcast clouds   4.1363   96.1285
# 22          Cascais      PT     72.75           clear sky  38.6979   -9.4215
# 24   Ribeira Grande      PT     72.00          few clouds  38.5167  -28.7000
# 26       Port Blair      IN     80.42     overcast clouds  11.6667   92.7500
# 29           Atuona      PF     78.06          few clouds  -9.8000 -139.0333
# 30   Port Elizabeth      ZA     61.11          few clouds -33.9180   25.5701
# 37         Saldanha      ZA     60.85    scattered clouds -33.0117   17.9442
# 38          Baghdad      IQ     76.91    scattered clouds  33.3406   44.4009
# 40            Vaini      TO     69.96       broken clouds -21.2000 -175.2000
# 41  Arraial Do Cabo      BR     78.76           clear sky -22.9661  -42.0278
# 44        Mahebourg      MU     75.49    scattered clouds -20.4081   57.7000
# 45          Sechura      PE     76.10     overcast clouds  -5.5569  -80.8222
# 46         Coquimbo      CL     60.53          few clouds -29.9533  -71.3436
# 48            Kapaa      US     75.52          light rain  22.0752 -159.3190
# 49          Kahului      US     76.84          few clouds  20.8947 -156.4700
# 50            Airai      TL     61.50       broken clouds  -8.9266  125.4092
# 53           Gaoual      GN     79.43     overcast clouds  11.7500  -13.2000
# 54           Faanui      PF     77.20     overcast clouds -16.4833 -151.7500
# 55         Altamira      BR     84.29          light rain  -3.2033  -52.2064
# 57      Bandarbeyla      SO     78.55           clear sky   9.4942   50.8122
# 58        Zacatepec      MX     81.37     overcast clouds  18.6500  -99.2000
# 65           Castro      BR     74.01          light rain -24.7911  -50.0119
# 66        Ugoofaaru      MV     81.63    scattered clouds   5.6667   73.0000
# 67          Halifax      CA     65.41     overcast clouds  44.6453  -63.5724
# 68          Tuy Hoa      VN     75.60     overcast clouds  13.0833  109.3000
# 69          Miranda      CO     80.65     overcast clouds   3.2499  -76.2281
# 71      Bay Roberts      CA     64.65          light rain  47.5999  -53.2648
#
#                                            Hotel Name
# 2                                   KORBEY D'OR OUEST
# 3                                     People ThankYou
# 4                                ibis Styles Karratha
# 7                                  The Halyards Hotel
# 11                                Hilo Hawaiian Hotel
# 17                                    Ramah Kost KITA
# 19                                          Kost Pria
# 22                            Hotel Vila Galé Cascais
# 24                                Quinta da Meia Eira
# 26  Welcomhotel By ITC Hotels, Bay Island, Port Blair
# 29                                        Villa Enata
# 30                             39 On Nile Guest House
# 37                                     Blue Bay Lodge
# 38                                      Baghdad Hotel
# 40                                Keleti Beach Resort
# 41                                Pousada Porto Praia
# 44                 Shandrani Beachcomber Resort & Spa
# 45                              Hospedaje Costa Bella
# 46                                 Punto de encuentro
# 48                Sheraton Kauai Coconut Beach Resort
# 49                                 Maui Seaside Hotel
# 50                                     Juvinal Martin
# 53                                       Hotel koliba
# 54                 Bora-Bora Pearl Beach Resort & Spa
# 55                                     Requinte Hotel
# 57                                        JABIR HOTEL
# 58                                  Villas El Paraíso
# 65                                     CHACARA BAILLY
# 66                                     Ungoofaaru Inn
# 67                                      Hotel Halifax
# 68                            CenDeluxe Hotel Tuy Hoa
# 69                   unidiversidad organica la utopia
# 71                                      Stonewall Inn

# %%
clean_hotel_df.count()
# Out:
# City                   234
# Country                234
# Max Temp               234
# Current Description    234
# Lat                    234
# Lng                    234
# Hotel Name             234
# dtype: int64

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
